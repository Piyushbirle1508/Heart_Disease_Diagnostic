# %% [markdown]
# # Heart Disease Diagnostic Analysis

# %% [markdown]
# importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the Dataset

data=pd.read_csv("Downloads/Heart_Disease.csv")

# %%
data.shape
# Out:
# (303, 14)

# %%
data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num
# 0   0     6    0
# 1   3     3    1
# 2   2     7    1
# 3   0     3    0
# 4   0     3    0

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %% [markdown]
# # Heart Disease Features Explaination
#
# Age (आयु):
#
# Short Name: age
# English: The person's age in years.
# Hindi: व्यक्ति की आयु वर्षों में।
#
# Sex:
# Short Name: sex
# English: The person's sex (1 = male, 0 = female).
# (1 = पुरुष, 0 = महिला)।
#
# Chest Pain (सीपी):
# Short Name: cp
# English: The chest pain experienced (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic).
# Hindi: मुख्य दुखि (सीपी) अनुभव किया गया छाती में दर्द (मूल्य 1: सामान्य एंजाइना, मूल्य 2: असामान्य एंजाइना, मूल्य 3: नॉन-एंजाइनल पेन, मूल्य 4: असंज्ञानात्मक)।
#
# Resting BP (आराम से बीपी):
# Short Name: trestbps
# English: The person's resting blood pressure (mm Hg on admission to the hospital).
# Hindi: व्यक्ति का आराम से ब्लड प्रेशर (हॉस्पिटल में प्रवेश पर मिमीमी ऑफ़ हाइड्राजन पैराबार)।
#
# Cholesterol (कोलेस्ट्रॉल):
# Short Name: chol
# English: The person's cholesterol measurement in mg/dl.
# Hindi: व्यक्ति का कोलेस्ट्रॉल माप (मि.ग्रा./डेसी.एल)।
#
# Fasting Sugar (उपवास शुगर):
# Short Name: fbs
# English: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false).
# Hindi: व्यक्ति की उपवास से ब्लड शुगर (> 120 मि.ग्रा./डेसी.एल, 1 = सत्य; 0 = असत्य)।
#
# Resting ECG (आराम से ईसीजी):
# Short Name: restecg
# English: Resting electrocardiographic measurement (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria).
# Hindi: आराम से इलेक्ट्रोकार्डियोग्राफिक माप (0 = सामान्य, 1 = एसटी-टी वेव असामान्यता है, 2 = एस्टेस के मानक के अनुसार संभावित या निश्चित बाएं वेंट्रिक्युलर हाइपरट्रोफी दिखा रहा है)।
#
# Max Heart Rate (अधिकतम हृदय दर):
# Short Name: thalach
# English: The person's maximum heart rate achieved.
# Hindi: व्यक्ति की अधिकतम हृदय दर जो प्राप्त की गई।
#
# Exercise Angina (व्यायाम एंजाइना):
# Short Name: exang
# English: Exercise-induced angina (1 = yes; 0 = no).
# Hindi: व्यायाम से उत्पन्न एंजाइना (1 = हाँ; 0 = नहीं)।
#
# ST Depression (एसटी डिप्रेशन):
# Short Name: oldpeak
# English: ST depression induced by exercise relative to rest.
# Hindi: विश्राम के साथ तुलनात्मक रूप से व्यायाम द्वारा उत्पन्न एसटी डिप्रेशन।
#
# Slope (ढलान):
# Short Name: slope
# English: The slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping).
# Hindi: चरम व्यायाम एसटी सेगमेंट की ढलान (मूल्य 1: ऊपर की ओर, मूल्य 2: समतल, मूल्य 3: नीचे की ओर)।
#
# Number of Vessels (नाड़ियों की संख्या):
# Short Name: ca
# English: The number of major vessels (0-3).
# Hindi: प्रमुख नाड़ियों की संख्या (0-3)।
#
# Thalassemia (थैलेसीमिया):
# Short Name: thal
# English: A blood disorder called thalassemia (3 = normal; 6 = fixed defect; 7 = reversible defect).
# Hindi: एक रक्त विकार जिसे थैलेसीमिया कहा जाता है (3 = सामान्य; 6 = स्थायी क्षति; 7 = पुनर्वासी क्षति)।
#
# Heart Disease (हृदय रोग):
# Short Name: num
# English: Heart disease (0 = no, 1 = yes).
# Hindi: हृदय रोग (0 = नहीं, 1 = हाँ)।

# %%
# to check datatype and any missing value in features

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  num       303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
# To check null value

data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %% [markdown]
# NO missing value in our datset

# %%
data["num"].value_counts()
# Out:
# 0    164
# 1    139
# Name: num, dtype: int64

# %%
# another method to know the count of values

data.groupby("num").size()
# Out:
# num
# 0    164
# 1    139
# dtype: int64

# %%
data["sex"].value_counts()
# Out:
# 1    206
# 0     97
# Name: sex, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# lets analyze our Target column which is num feature

# %%
y = data["num"]

sns.countplot(y)


target_temp = data.num.value_counts()

print(target_temp)
# Out:
# 0    164
# 1    139
# Name: num, dtype: int64
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print("Percentage of patience without heart problems: "+str(round(target_temp[0]*100/303,2)))
print("Percentage of patience with heart problems: "+str(round(target_temp[1]*100/303,2)))
# Out:
# Percentage of patience without heart problems: 54.13
# Percentage of patience with heart problems: 45.87

# %%
df = pd.DataFrame(data)

# Create a cross-tabulation (frequency table)
cross_tab = pd.crosstab(df['sex'], df['num'], margins=True, margins_name='Total')

# Calculate percentages
percentages = cross_tab.div(cross_tab['Total'], axis=0) * 100

# Display the result
print("Cross-tabulation of sex and heart disease:")
print(cross_tab)

print("\nPercentage of individuals with and without heart disease:")
print(percentages)
# Out:
# Cross-tabulation of sex and heart disease:
# num      0    1  Total
# sex
# 0       72   25     97
# 1       92  114    206
# Total  164  139    303
#
# Percentage of individuals with and without heart disease:
# num            0          1  Total
# sex
# 0      74.226804  25.773196  100.0
# 1      44.660194  55.339806  100.0
# Total  54.125413  45.874587  100.0

# %% [markdown]
# here we get to know that there are more numbers of mans having the heart disease problem as compare to females

# %% [markdown]
# # Analysing the 'Chest Pain Type' feature

# %%
data["cp"].unique()
# Out:
# array([1, 4, 3, 2], dtype=int64)

# %%
plt.figure(figsize=(7,5))
sns.barplot(data['cp'],data['num'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cp', ylabel='num'>

# %% [markdown]
# We notice, that chest pain of '1', i.e. the ones with typical angina are much less likely to have heart problems

# %%
#Count Plot Creation of Chest Pain Experienced using MatplotLib and Seaborn

sns.countplot(x=data['num'], hue='cp', data=data, order=[0,1])
plt.title('Chest Pain Experienced', fontsize=17)
plt.xlabel('Heart Disease',fontsize=15)
plt.ylabel('Counts',fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# It seems people having asymptomatic chest pain have a higher chance of heart disease

# %% [markdown]
# Asymptomatic Chest pain means neither causing nor exhibiting symptoms of Heart disease.

# %%
#Countplot Creation of Population Age using MatplotLib and Seaborn

plt.figure(figsize=(15,7))
ax=sns.countplot(x='age', data=data)
plt.title('Population Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Count', fontsize=15)

# Add count labels on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.show()

# %% [markdown]
#               we will divided the age into young people, middle_aged,elderly by looking at the age ranges.

# %%
#Statistical Analysis

Min_Age=data['age'].min()
Max_Age=data['age'].max()
Mean_Age=data['age'].mean()
print("Minimum Age =",Min_Age)
print("Maximum Age =",Max_Age)
print("Mean Age =",Mean_Age)
# Out:
# Minimum Age = 29
# Maximum Age = 77
# Mean Age = 54.43894389438944

# %%
#Categorical Analysis

Young_Ages=data[(data['age']>=29) & (data['age']<40)]
Middle_Ages=data[(data['age']>=40) & (data['age']<55)]
Elderly_Ages=data[(data['age']>=55)]
print('Young Ages =',len(Young_Ages))
print('Middle Ages =',len(Middle_Ages))
print('Elderly Ages =',len(Elderly_Ages))
# Out:
# Young Ages = 15
# Middle Ages = 128
# Elderly Ages = 160

# %%
#Bar Plot Creation of Age Category using MatplotLib and Seaborn

sns.barplot(x=['Young_Ages','Middle_Ages','Elderly_Ages'], y=[len(Young_Ages), len(Middle_Ages), len(Elderly_Ages)])
plt.title('Age Category', fontsize=17)
plt.xlabel('Age Range', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()

# %%
#Converting Numerical Data into Categorical Data

def age_range(row):
    if row>=29 and row<40:
        return 'Young Age'
    elif row>=40 and row<55:
        return 'Middle Age'
    elif row>=55:
        return 'Elder Age'

# %%
#Applying converted data into our dataset with new column - Age_Range

data['Age_Range']=data['age'].apply(age_range)
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   1       145   233    1        2      150      0      2.3      3
# 1   67    1   4       160   286    0        2      108      1      1.5      2
# 2   67    1   4       120   229    0        2      129      1      2.6      2
# 3   37    1   3       130   250    0        0      187      0      3.5      3
# 4   41    0   2       130   204    0        2      172      0      1.4      1
#
#    ca  thal  num   Age_Range
# 0   0     6    0   Elder Age
# 1   3     3    1   Elder Age
# 2   2     7    1   Elder Age
# 3   0     3    0   Young Age
# 4   0     3    0  Middle Age

# %%
#Swarm Plot Creation of Gender Based Age Category using MatplotLib and Seaborn

plt.figure(figsize=(10,7))
sns.swarmplot(x='Age_Range', y='age', hue='sex', data=data, order=['Young Age','Middle Age','Elder Age'], palette='Oranges_r')
plt.title('Gender Based Age Category', fontsize=17)
plt.xlabel('Age Category', fontsize=15)
plt.ylabel('Age', fontsize=15)
plt.show()

# %%
x=pd.crosstab(data['Age_Range'],data["sex"])
x
# Out:
# sex          0    1
# Age_Range
# Elder Age   57  103
# Middle Age  35   93
# Young Age    5   10

# %% [markdown]
# in young, middle and elder males are more then females

# %%
#Count Plot Creation of Heart Disease Based On Age Category using MatplotLib and Seaborn

plt.figure(figsize=(7,5))
hue_order=['Young Age', 'Middle Age', 'Elder Age']
sns.countplot(x='num', hue=data['Age_Range'], data=data, hue_order=hue_order, palette='Pastel1')
plt.title('Heart Disease Based On Age Category', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.show()

# %% [markdown]
# 0 is for no disease and 1 is for disease

# %% [markdown]
# Elder Age People are most affected by Heart Disease AND Middle Age People are mostly FREE from any kind of Heart Disease

# %% [markdown]
# # Chest pain Based on Gender Wise

# %%
sns.countplot(data['sex'])
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(x=data['sex'], hue='cp', data=data)
plt.title('Chest Pain Based On Gender', fontsize=17)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# 0 is the female and 1 is the male and we can see that a higher number of men are suffering from Asymptomatic type of Chest Pain

# %% [markdown]
# # chest pain based on Age category

# %%
plt.figure(figsize=(7,5))
sns.countplot(x=data['Age_Range'], hue='cp', data=data, order=['Young Age', 'Middle Age', 'Elder Age'], palette='hls')
plt.title('Chest Pain Based On Age Category', fontsize=17)
plt.xlabel('Age Category', fontsize=15)
plt.ylabel('Counts', fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# we have a very high number of Asymptomatic Pain in Elderly age Category

# %%
#Bar Plot Creation of Person's Resting Blood Pressure (mm Hg) using MatplotLib and Seaborn

plt.figure(figsize=(11,6))
ax=sns.barplot(x='sex', y='trestbps', data=data, palette='plasma')
plt.title("Blood Pressure", fontsize=17)
plt.xlabel('Sex', fontsize=15)
plt.ylabel("Person's Resting Blood Pressure (mm Hg)", fontsize=12)

# Add labels at the top of each bar
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), f'{p.get_height():.2f}', 
            ha='center', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# Blood Pressure Rate is almost equal in Males and Females

# %% [markdown]
# # Blood Pressure vs Age

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='age', y='trestbps', data=data, color='g')
plt.title('Blood Pressure VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Blood Pressure', fontsize=15)
plt.show()

# %% [markdown]
# here Blood Pressure increases between age of 51 to 60 and somehow continue the pattern till 70

# %% [markdown]
# # cholestrol level vs Gender

# %%
sns.boxenplot(x='sex', y='chol', data=data, palette='turbo')
plt.title("Cholestrol Level Based On Gender", fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel("Cholestrol", fontsize=15)
plt.show()

# %% [markdown]
# Females has Higher cholestrol then mans

# %%
#Line Plot Creation of Cholestrol VS Age using MatplotLib and Seaborn

sns.lineplot(x='age', y='chol', data=data, color='b')
plt.title('Cholestrol VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('Cholestrol', fontsize=15)
plt.show()

# %% [markdown]
# cholestrol is increasing in the age of 50-60

# %%
#Line Plot Creation of ST Depression VS Age using MatplotLib and Seaborn

sns.lineplot(x='age', y='oldpeak', data=data, color='g')
plt.title('ST Depression VS Age', fontsize=17)
plt.xlabel('Age', fontsize=15)
plt.ylabel('ST depression', fontsize=15)
plt.show()

# %% [markdown]
# -> we can observe from here that ST depression mostly increases bw the age group of 30-40

# %% [markdown]
# -> ST depression refers to a finding on an electrocardiogram, wherein the trace in the ST segment is abnormally low below the baseline.

# %% [markdown]
# # Blood Pressure vs Heart Disease

# %%
sns.barplot(x='num', y='trestbps', data=data, palette='husl')
plt.title('Blood Pressure VS Heart Disease', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Blood Pressure', fontsize=15)
plt.show()

# %% [markdown]
# -> Higher Blood Pressure Level results Chances Of Heart Disease

# %% [markdown]
# # Exercise With Angina VS Heart Disease

# %%
#Bar Plot Creation of Exercise With Angina VS Heart Disease using MatplotLib and Seaborn

sns.barplot(x='num', y='exang', data=data, palette='viridis')
plt.title('Exercise With Angina VS Heart Disease', fontsize=17)
plt.xlabel('Heart Disease', fontsize=15)
plt.ylabel('Exercise With Angina', fontsize=15)
plt.show()

# %% [markdown]
# -> If you suffer from Angina, you may be concerned that exercise will make your symptoms worse.

# %%
#Bar Plot Creation of Fasting Blood Sugar VS Gender using MatplotLib and Seaborn

sns.barplot(y='fbs', x='sex', data=data, palette='hsv')
plt.title(' Fasting Blood Sugar VS Gender', fontsize=17)
plt.xlabel('Sex', fontsize=15)
plt.ylabel('Fasting Blood Sugar', fontsize=15)
plt.show()

# %% [markdown]
# -> Males have high no of Fasting Blood Sugar over 120

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data.corr(), annot=True, linewidth=3)
# Out:
# <AxesSubplot:>
